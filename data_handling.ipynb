# %% [markdown]
# <a href="https://colab.research.google.com/github/anish3333/Basic-JS-Proejcts/blob/main/data_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # handling api data

# %%
import pandas as pd
import requests

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNDFiYzYyOWMyZGZjZDc4Mzg3NDNjY2FmODc4YzAwNSIsInN1YiI6IjY1ZWMzNmVkNWJjZTllMDE4NjQ3MGU5ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.FHOBIG-iw07tiQraAqgbliDKPPx556JIO9ou27VbRvs"
}

df = pd.DataFrame()
for i in range(4, 50):
  url = f"https://api.themoviedb.org/3/tv/top_rated?language=en-US&page={i}"
  response = requests.get(url, headers=headers)
  data = response.json().get('results')
  if data:
    temp_df = pd.DataFrame(data)[['id', 'original_name']]
    # print(temp_df.head())
    df = pd.concat([df, temp_df], ignore_index=True)
  else:
    print("No data found for page", i)
pd.set_option('display.max_columns', None)

# %%
df.to_csv('anish.csv')
df.head(df.shape[0])
# Out:
#          id         original_name
# 0     77721           ３Ｄ彼女　リアルガール
# 1      2316            The Office
# 2    105248      サイバーパンク：エッジランナーズ
# 3     12313         Shadow Hunter
# 4     98214              Villanos
# ..      ...                   ...
# 915    1830  Tiny Toon Adventures
# 916   95259               Dare Me
# 917   82282      Like, la Leyenda
# 918    2973          Life on Mars
# 919   80986         DC's Stargirl
#
# [920 rows x 2 columns]
